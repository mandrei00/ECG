# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
FILENAME = "1208.txt"
signal = np.array([])
with open(FILENAME, "r", encoding="utf-8") as f:
    for i in range(525_000):
        signal = np.append(signal, float(f.readline().replace(" ", "")))

# %%
time = np.linspace(start=0, stop=210, num=525_000)

# %%
signal.shape
time.shape
# Out:
# (525000,)

# %%
N = 1000
plt.plot(time[:N], signal[:N])
